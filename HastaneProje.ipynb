-- %% [markdown]
-- # [dbo].[Tbl_Brans]

-- %%
USE [HastaneProje]
GO

-- %%
/****** Object:  Table [dbo].[Tbl_Brans]    Script Date: 3.03.2024 10:53:30 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Tbl_Brans](
	[brans_id] [int] IDENTITY(1,1) NOT NULL,
	[brans_ad] [varchar](30) NULL,
PRIMARY KEY CLUSTERED 
(
	[brans_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Tbl_Doktor]

-- %%
/****** Object:  Table [dbo].[Tbl_Doktor]    Script Date: 3.03.2024 10:53:31 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Tbl_Doktor](
	[doktor_id] [int] IDENTITY(1,1) NOT NULL,
	[doktor_ad] [varchar](20) NULL,
	[doktor_soyad] [varchar](20) NULL,
	[brans_id] [int] NULL,
	[doktor_tc] [char](11) NULL,
	[doktor_sifre] [varchar](10) NULL,
	[doktor_cinsiyet] [varchar](5) NULL,
PRIMARY KEY CLUSTERED 
(
	[doktor_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Tbl_Duyuru]

-- %%
/****** Object:  Table [dbo].[Tbl_Duyuru]    Script Date: 3.03.2024 10:53:31 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Tbl_Duyuru](
	[duyuru_id] [smallint] IDENTITY(1,1) NOT NULL,
	[duyuru] [varchar](200) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Tbl_Hasta]

-- %%
/****** Object:  Table [dbo].[Tbl_Hasta]    Script Date: 3.03.2024 10:53:31 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Tbl_Hasta](
	[hasta_id] [int] IDENTITY(1,1) NOT NULL,
	[hasta_ad] [varchar](20) NULL,
	[hasta_soyad] [varchar](20) NULL,
	[hasta_tc] [char](11) NULL,
	[hasta_telefon] [varchar](15) NULL,
	[hasta_sifre] [varchar](10) NULL,
	[hasta_cinsiyet] [varchar](5) NULL,
PRIMARY KEY CLUSTERED 
(
	[hasta_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Tbl_Randevu]

-- %%
/****** Object:  Table [dbo].[Tbl_Randevu]    Script Date: 3.03.2024 10:53:31 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Tbl_Randevu](
	[randevu_id] [int] IDENTITY(1,1) NOT NULL,
	[randevu_tarih] [varchar](30) NULL,
	[randevu_saat] [varchar](5) NULL,
	[randevu_brans] [varchar](30) NULL,
	[randevu_doktor] [varchar](50) NULL,
	[randevu_durum] [bit] NULL,
	[hasta_tc] [char](11) NULL,
	[hasta_sikayet] [varchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[randevu_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Tbl_Sekreter]

-- %%
/****** Object:  Table [dbo].[Tbl_Sekreter]    Script Date: 3.03.2024 10:53:31 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Tbl_Sekreter](
	[sekreter_id] [int] IDENTITY(1,1) NOT NULL,
	[sekreter_ad] [varchar](20) NULL,
	[sekreter_soyad] [varchar](20) NULL,
	[sekreter_tc] [char](11) NULL,
	[sekreter_sifre] [varchar](10) NULL,
PRIMARY KEY CLUSTERED 
(
	[sekreter_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF_Tbl_Randevu_randevu_durum]

-- %%
ALTER TABLE [dbo].[Tbl_Randevu] ADD  CONSTRAINT [DF_Tbl_Randevu_randevu_durum]  DEFAULT ((0)) FOR [randevu_durum]
GO

-- %% [markdown]
-- # [FK_Tbl_Doktor_Tbl_Brans]

-- %%
ALTER TABLE [dbo].[Tbl_Doktor]  WITH CHECK ADD  CONSTRAINT [FK_Tbl_Doktor_Tbl_Brans] FOREIGN KEY([brans_id])
REFERENCES [dbo].[Tbl_Brans] ([brans_id])
GO
ALTER TABLE [dbo].[Tbl_Doktor] CHECK CONSTRAINT [FK_Tbl_Doktor_Tbl_Brans]
GO
